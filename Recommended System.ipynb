# %% [markdown]
# <a href="https://colab.research.google.com/github/tushars95/All-about-Indian-Economy/blob/master/Recommended%20System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install surprise
# Out:
# ...
#     100% |████████████████████████████████| 3.3MB 7.7MB/s
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/ec/c0/55/3a28eab06b53c220015063ebbdb81213cd3dcbb72c088251ec
# Successfully built scikit-surprise
# ...

# %%
import pandas as pd
import numpy as np
import surprise

# %%
ratings=pd.read_csv('https://raw.githubusercontent.com/skathirmani/datasets/master/ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1       31     2.5
# 1       1     1029     3.0
# 2       1     1061     3.0
# 3       1     1129     2.0
# 4       1     1172     4.0

# %%
from surprise import Reader, Dataset , KNNWithMeans
reader =Reader(rating_scale =(1,5))

data =Dataset.load_from_df(ratings[['userId','movieId','rating']],reader)

sim_options = {'user_based':True, 'name':'cosine'}
model = KNNWithMeans(sim_options =sim_options)
model.fit(data.build_full_trainset())
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
model.predict(1,1)
# Out:
# Prediction(uid=1, iid=1, r_ui=None, est=2.595538918455837, details={'actual_k': 40, 'was_impossible': False})
